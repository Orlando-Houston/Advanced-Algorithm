# %%
import matplotlib.pyplot as plt
import numpy as np
import timeit
import time
import math
import random
plt.rcParams['figure.figsize'] = [10, 6]

# %% [markdown]
# ## we wanted to increment the number entries in the same linear search code snippet then look at the runtime and complexity

# %%
def linear_search(lst,target):
    for i in range(len(lst)):
        if(lst[i]== target):
            return i
    return -1
lst=np.linspace(1, 10_000, 100, dtype=int)
target=2
print(linear_search(lst,target))

if __name__ == '__main__':
    import timeit
    print(timeit.timeit("linear_search('lst','target')", setup="from __main__ import linear_search",number=1))
# Out:
# -1
# 1.8999999156221747e-06

# %%
import matplotlib.pyplot as plt
target = range(1, 31, 10)
y_1 = []
y_2 = []


for n in target:
    lst= list(range(0, n))
    y_1.append(timeit.timeit(lambda: linear_search(lst, 1000)))
    y_2.append(timeit.timeit(lambda: linear_search(target, 0)))
    
# %matplotlib notebook

import matplotlib.pyplot as plt
plt.plot(target,y_1,'r') 
plt.plot(target,y_2,'g') 

plt.ylim(ymin=0)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def linear_search_3(lst,target):
    for i in range(0,len(lst)):
        if(lst[i]== target):
            return i
    return -1

lst=np.linspace(1, 50_000_00, 50000, dtype=int)

target=2
print(linear_search_3(lst,target))

if __name__ == '__main__':
    import timeit
    print(timeit.timeit("linear_search_3('lst','target')", setup="from __main__ import linear_search_3",number=1))
# Out:
# -1
# 5.999999757477781e-06

# %%
import matplotlib.pyplot as plt
target = range(1, 31, 10)
z_1 = []
z_2 = []


for n in target:
    lst= list(range(0, n))
    z_1.append(timeit.timeit(lambda: linear_search_3(lst, 10000)))
    z_2.append(timeit.timeit(lambda: linear_search_3(target, 0)))
    
# %matplotlib notebook

import matplotlib.pyplot as plt
plt.plot(target,z_1,'b') 
plt.plot(target,z_2,'g') 

plt.ylim(ymin=0)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
#
# ## then we wanted to show the time complexity of these two code snippets in a graph

# %%
import matplotlib.pyplot as plt
target = range(1, 31, 10)
t_1 = []
t_2 = []
t_3 = []
t_4 = []

for n in target:
    lst = list(range(0, n))
    t_1.append(timeit.timeit(lambda: linear_search(lst, 1000)))
    t_2.append(timeit.timeit(lambda: linear_search(lst, 0)))
    t_3.append(timeit.timeit(lambda: linear_search_3(lst, 1000)))
    t_4.append(timeit.timeit(lambda: linear_search_3(lst, 0)))

# %matplotlib notebook

import matplotlib.pyplot as plt
plt.plot(target,t_1,'r') 
plt.plot(target,t_2,'g') 
plt.plot(target,t_3,'b') 
plt.plot(target,t_4,'c')
plt.ylim(ymin=0)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from sklearn.linear_model import  LinearRegression
from sklearn import linear_model

# %%
#reg= linear_model.LinearRegression()
#reg.fit(linear_search,linear_search_3)
#print(reg.predict)
#print(reg.score)

# %%
# https://realpython.com/binary-search-python/

# %% [markdown]
# ## Binary Search
# * Binary search
# * Binary search runs with O(log n) runtime complexity.

# %%
def contains(lst, target):
    lo = 0
    hi = len(lst)-1
    while lo <= hi:
        mid = (lo + hi) // 2
        if target < lst[mid]:
            hi = mid - 1
        elif target > lst[mid]:
            lo = mid + 1
        else:
            return True
    else:
        return False
    
    

ns = np.linspace(10, 100, 100, dtype=int)
ts = [timeit.timeit('contains(lst, 0)', 
                    setup='lst=list(range({}))'.format(n),
                    globals=globals(),
                    number=1000)
      for n in ns]


plt.plot(ns, ts, 'or')
degree = 4
coeffs = np.polyfit(ns, ts, degree)
p = np.poly1d(coeffs)
plt.plot(ns, [p(n) for n in ns], '-b');

# %%
# searches for an item in a list using linear search
def contains_1(lst, target):
    lo = 0
    hi = len(lst)-1
    while lo <= hi:
        mid = (lo + hi) // 2
        if target < lst[mid]:
            hi = mid - 1
        elif target > lst[mid]:
            lo = mid + 1
        else:
            return True
    else:
        return False

# %%
ns_1 =np.linspace(10,10_000, 100, dtype=int)

# %%
ts_1 = [timeit.timeit('contains_1(lst, 0)', 
                    setup='lst=list(range({}))'.format(n),
                    globals=globals(),
                    number=1000)
      for n in ns_1]

# %%
plt.plot(ns_1, ts_1, 'g')
degree = 4
coeffs = np.polyfit(ns_1, ts_1, degree)
p = np.poly1d(coeffs)
plt.plot(ns_1, [p(n) for n in ns_1], '-b');

# %%
# searches for an item in a list using linear search
def contains_2(lst, target):
    lo = 0
    hi = len(lst)-1
    while lo <= hi:
        mid = (lo + hi) // 2
        if target < lst[mid]:
            hi = mid - 1
        elif target > lst[mid]:
            lo = mid + 1
        else:
            return True
    else:
        return False

# %%
ns_2 =np.linspace(10,100000, 100, dtype=int)

# %%
ts_2 = [timeit.timeit('contains_2(lst, 0)', 
                    setup='lst=list(range({}))'.format(n),
                    globals=globals(),
                    number=1000)
      for n in ns_2]

# %%
plt.plot(ns_2, ts_2, 'r')
degree = 4
coeffs = np.polyfit(ns_2, ts_2, degree)
p = np.poly1d(coeffs)
plt.plot(ns_2, [p(n) for n in ns_2], '-b');

# %%
# searches for an item in a list using linear search
def contains_3(lst, target):
    lo = 0
    hi = len(lst)-1
    while lo <= hi:
        mid = (lo + hi) // 2
        if target < lst[mid]:
            hi = mid - 1
        elif target> lst[mid]:
            lo = mid + 1
        else:
            return True
    else:
        return False

# %%
ns_3 =np.linspace(10,1000000 , 100, dtype=int)

# %%
ts_3 = [timeit.timeit('contains_3(lst_1, 0)', 
                    setup='lst=list(range({}))'.format(n),
                    globals=globals(),
                    number=1000)
      for n in ns_3]

# %%
plt.plot(ns_3, ts_3, 'or')
degree = 4
coeffs = np.polyfit(ns_3, ts_3, degree)
p = np.poly1d(coeffs)
plt.plot(ns_3, [p(n) for n in ns_3], '-b');

# %%
def binary_search_recursive(lst, target, start, end):
    if start > end:
        return -1

    mid = (start + end) // 2
    if target == lst[mid]:
        return mid

    if target < lst[mid]:
        return binary_search_recursive(lst,target, start, mid-1)
    else:
        return binary_search_recursive(lst,target, mid+1, end)
    
target = 2
lst = np.linspace(1, 500, 500, dtype=int)

print("Searching for {}".format(target))
print("Index of {}: {}".format(target, binary_search_recursive(lst, target, 0, len(lst))))

if __name__ == '__main__':
    import timeit
    print(timeit.timeit("binary_search_recursive('lst','target','start','end')", setup="from __main__ import binary_search_recursive",number=1))
# Out:
# Searching for 2
# Index of 2: 1
# 1.2000000424450263e-06

# %%
import matplotlib.pyplot as plt
target = range(1, 31, 10)
b_1 = []
b_2 = []


for n in target:
    lst= list(range(0, n))
    b_1.append(timeit.timeit(lambda: binary_search_recursive(lst,10000)))
    b_2.append(timeit.timeit(lambda: binary_search_recursive(target, 0)))
    
# %matplotlib notebook

import matplotlib.pyplot as plt
plt.plot(target,b_1,'b') 
plt.plot(target,b_2,'g') 

plt.ylim(ymin=0)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-37332d118b01> in <module>
#       7 for n in target:
#       8     lst= list(range(0, n))
# ----> 9     b_1.append(timeit.timeit(lambda: binary_search_recursive(lst,10000)))
#      10     b_2.append(timeit.timeit(lambda: binary_search_recursive(target, 0)))
#      11
#
# C:\ANACONDA\lib\timeit.py in timeit(stmt, setup, timer, number, globals)
#     231            number=default_number, globals=None):
#     232     """Convenience function to create Timer object and call timeit method."""
# --> 233     return Timer(stmt, setup, timer, globals).timeit(number)
#     234
#     235 def repeat(stmt="pass", setup="pass", timer=default_timer,
#
# C:\ANACONDA\lib\timeit.py in timeit(self, number)
#     175         gc.disable()
#     176         try:
# --> 177             timing = self.inner(it, self.timer)
# ...

# %%
def binary_search_recursive_1(lst, target, start, end):
    if start > end:
        return -1

    mid = (start + end) // 2
    if target == lst[mid]:
        return mid

    if target < lst[mid]:
        return binary_search_recursive_1(lst,target, start, mid-1)
    else:
        return binary_search_recursive_1(lst,target, mid+1, end)
    
target = 2
lst = np.linspace(1, 50_000_00, 50000, dtype=int)

print("Searching for {}".format(target))
print("Index of {}: {}".format(target, binary_search_recursive_1(lst, target, 0, len(lst))))

if __name__ == '__main__':
    import timeit
    print(timeit.timeit("binary_search_recursive_1('lst','target','start','end')", setup="from __main__ import binary_search_recursive_1",number=1))
# Out:
# Searching for 2
# Index of 2: -1
# 1.2999998943996616e-06

# %% [markdown]
# ### iterative

# %%
def binary_search_iterative(lst, target):
    mid = 0
    start = 0
    end = len(lst)
    step = 0

    while (start <= end):
        print("Subarray in step {}: {}".format(step, str(lst[start:end+1])))
        step = step+1
        mid = (start + end) // 2

        if target == lst[mid]:
            return mid

        if target < lst[mid]:
            end = mid - 1
        else:
            start = mid + 1
    return -1

# %%
#lst = np.linspace(1, 500, 500, dtype=int)
import random
lst =random.sample(range(0, 1000),500) 
target=2

print("Searching for {} in {}".format(target, lst))
print("Index of {}: {}".format(target, binary_search_iterative(lst,target)))
#if __name__ == '__main__':
 #   import timeit
 #   print(timeit.timeit("binary_search_iterative('lst','target')", setup="from __main__ import binary_search_iterative",number=1))
# Out:
# Searching for 2 in [108, 170, 668, 986, 835, 996, 952, 891, 494, 261, 262, 144, 832, 881, 585, 10, 493, 179, 629, 70, 174, 61, 31, 403, 19, 329, 251, 115, 257, 510, 716, 653, 50, 833, 215, 209, 380, 581, 437, 707, 673, 974, 342, 128, 838, 640, 741, 270, 662, 32, 469, 545, 372, 409, 742, 843, 980, 727, 101, 188, 146, 979, 682, 140, 148, 946, 138, 882, 219, 311, 553, 445, 367, 162, 632, 238, 516, 622, 305, 110, 291, 301, 926, 514, 522, 766, 937, 451, 418, 690, 298, 817, 730, 990, 116, 971, 658, 447, 436, 410, 861, 992, 149, 543, 206, 482, 575, 154, 562, 517, 45, 639, 892, 538, 17, 822, 987, 508, 474, 957, 856, 685, 3, 359, 7, 659, 767, 959, 203, 848, 521, 733, 617, 230, 869, 275, 100, 344, 777, 844, 734, 448, 458, 611, 973, 283, 441, 779, 607, 343, 795, 902, 614, 389, 498, 915, 939, 531, 289, 467, 609, 570, 810, 405, 327, 481, 425, 379, 432, 746, 519, 645, 455, 620, 250, 393, 876, 524, 753, 975, 933, 717, 25, 700, 967, 770, 255, 36, 576, 124, 818, 419, 904, 41, 299, 487, 509, 612, 254,
# ...

# %%
import matplotlib.pyplot as plt
target = range(1, 31, 10)
b_1 = []
b_2 = []


for n in target:
    lst= list(range(0, n))
    b_1.append(timeit.timeit(lambda: binary_search_iterative(lst,10000)))
    b_2.append(timeit.timeit(lambda: binary_search_iterative(target, 0)))
    
    
# %matplotlib notebook

import matplotlib.pyplot as plt
plt.plot(target,b_1,'b') 
plt.plot(target,b_2,'g') 


plt.ylim(ymin=0)
plt.show()
# Out:
# Subarray in step 0: [0]
# Subarray in step 1: []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-65-e1bad4fff8ad> in <module>
#       7 for n in target:
#       8     lst= list(range(0, n))
# ----> 9     b_1.append(timeit.timeit(lambda: binary_search_iterative(lst,10000)))
#      10     b_2.append(timeit.timeit(lambda: binary_search_iterative(target, 0)))
#      11
#
# C:\ANACONDA\lib\timeit.py in timeit(stmt, setup, timer, number, globals)
#     231            number=default_number, globals=None):
#     232     """Convenience function to create Timer object and call timeit method."""
# --> 233     return Timer(stmt, setup, timer, globals).timeit(number)
#     234
#     235 def repeat(stmt="pass", setup="pass", timer=default_timer,
#
# C:\ANACONDA\lib\timeit.py in timeit(self, number)
#     175         gc.disable()
#     176         try:
# ...

# %%
def BinarySearch(lst, target):
    first = 0
    last = len(lys)-1
    index = -1
    while (first <= last) and (index == -1):
        mid = (first+last)//2
        if lst[mid] == target:
            index = mid
        else:
            if target<lst[mid]:
                last = mid -1
            else:
                first = mid +1
    return index

# %%
BinarySearch([10,20,30,40,50], 20)
# Out:
# 1

# %%
import matplotlib.pyplot as plt
target = range(1, 31, 10)
b_1 = []
b_2 = []


for n in target:
    lst= list(range(0, n))
    b_1.append(timeit.timeit(lambda: BinarySearch(lst,10000)))
    b_2.append(timeit.timeit(lambda: BinarySearch(target, 0)))
    
    
# %matplotlib notebook

import matplotlib.pyplot as plt
plt.plot(target,b_1,'b') 
plt.plot(target,b_2,'g') 


plt.ylim(ymin=0)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### plot for iterating

# %% [markdown]
# ## then we wanted to show the time complexity of these two code snippets in a graph

# %%
# Out:
# 1

# %% [markdown]
# ## we wanted to increment the number entries in the same linear search code snippet then look at the runtime and complexity

# %%
def linear_search(A, x):
    answer = -1
    for i in range(0, len(A)):
        if A[i] == x: answer = i
    return answer

# %%
linear_search([10, 5, 9, 9], 10)
#if __name__ == '__main__':
    #import timeit
   # print(timeit.timeit("linear_search('A','x')", setup="from __main__ import linear_search",number=1))
# Out:
# 2.200000380980782e-06

# %%
def better_linear_search(A, x):
    for i in range(0, len(A)):
        if A[i] == x: return i
    return -1

# %%
better_linear_search([10, 5, 9, 9], 9)
#if __name__ == '__main__':
    #import timeit
    #print(timeit.timeit("better_linear_search('A','x')", setup="from __main__ import better_linear_search",number=1))
# Out:
# 2

# %%
import matplotlib.pyplot as plt
x = range(1, 31, 10)
y_1 = []
y_2 = []
y_3 = []
y_4 = []

for n in x:
    A = list(range(0, n))
    y_1.append(timeit.timeit(lambda: linear_search(A, 1000)))
    y_2.append(timeit.timeit(lambda: linear_search(A, 0)))
    y_3.append(timeit.timeit(lambda: better_linear_search(A, 1000)))
    y_4.append(timeit.timeit(lambda: better_linear_search(A, 0)))

# %matplotlib notebook

import matplotlib.pyplot as plt
plt.plot(x,y_1,'r') 
plt.plot(x,y_2,'g') 
plt.plot(x,y_3,'b') 
plt.plot(x,y_4,'c')
plt.ylim(ymin=0)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-098561bc1a3e> in <module>
#       7
#       8 for n in x:
# ----> 9     A = list(range(0, n))
#      10     y_1.append(timeit.timeit(lambda: linear_search(A, 1000)))
#      11     y_2.append(timeit.timeit(lambda: linear_search(A, 0)))
#
# TypeError: 'list' object is not callable

# %%
# https://pythonfundu.blogspot.com/2019/02/timeit-in-python-with-examples.html

# %%
import timeit

# %%
# binary search function
def binary_search(mylist, find):
    while len(mylist) > 0:
        mid = (len(mylist))//2
    if mylist[mid] == find:
        return True
    elif mylist[mid] < find:
        mylist = mylist[:mid]
    else:
        mylist = mylist[mid + 1:]
        
        return False


# compute binary search time
def binary_time():
    SETUP_CODE = '''
from __main__ import binary_search
from random import randint'''

    TEST_CODE = '''
mylist = [x for x in range(10000)]
find = randint(0, len(mylist))
binary_search(mylist, find)'''
 
 # timeit.repeat statement
    times = timeit.repeat(setup = SETUP_CODE,stmt = TEST_CODE,repeat = 3,number = 10000)

 # priniting minimum exec. time
print('Binary search time: {}'.format(min(times)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-4f599c0e8d5f> in <module>
#      25
#      26  # timeit.repeat statement
# ---> 27 times = timeit.repeat(setup = SETUP_CODE,stmt = TEST_CODE,repeat = 3,number = 10000)
#      28
#      29  # priniting minimum exec. time
#
# NameError: name 'SETUP_CODE' is not defined

# %%
# compute linear search time
def linear_time():
    SETUP_CODE = '''
from __main__ import linear_search
from random import randint'''
 
   TEST_CODE = '''
mylist = [x for x in range(10000)]
find = randint(0, len(mylist))
linear_search(mylist, find)
 '''
 # timeit.repeat statement
 times = timeit.repeat(setup = SETUP_CODE,
      stmt = TEST_CODE,
      repeat = 3,
      number = 10000)

 # priniting minimum exec. time
 print('Linear search time: {}'.format(min(times)))

# %%
if __name__ == "__main__":
    linear_time()
    binary_time()

# %% [markdown]
# # https://blog.jovian.ai/complexity-analysis-of-linear-and-binary-search-using-python-4295630ceb80

# %%
# !pip install jovian --upgrade --quiet
import jovian
# Out:
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# selenium 4.0.0 requires urllib3[secure]~=1.26, but you'll have urllib3 1.25.11 which is incompatible.

# %%
project='python-binary-search-bonus-questions'

# %%
import matplotlib.pyplot as plt
import numpy as np
import timeit
import time
from timeit import Timer

import math
import random
plt.rcParams['figure.figsize'] = [10, 6]

# %%
from jovian.pythondsa import evaluate_test_case, evaluate_test_cases

# %%
test = {
    'input': {
        'nums': [19, 25, 29, 3, 5, 6, 7, 9, 11, 14]
    },
    'output': 3
}

# %%
tests = []

# %%
# A list of size 10 rotated 3 times.
tests.append({
    'input': {
        'nums': [19, 25, 29, 3, 5, 6, 7, 9, 11, 14]
    },
    'output': 3
})

# %%
# A list of size 8 rotated 5 times.
tests.append({
    'input': {
        'nums': [7, 9, 13, 14, 17, 2, 4, 5]
    },
    'output': 5
})

# %%
# A list that wasn't rotated at all.
tests.append({
    'input': {
        'nums': [2, 4, 6, 8, 9, 10]
    },
    'output': 0
})

# %%
# A list that was rotated just once.
tests.append({
    'input': {
        'nums': [23, 4, 7, 9, 13, 16, 20, 22]
    },
    'output': 1
})

# %%
# A list that was rotated n-1 times, where n is the size of the list.
tests.append({
    'input': {
        'nums': [3, 5, 7, 9, 10, 13, 15, 1]
    },
    'output': 7
})

# %%
# A list that was rotated n times, where n is the size of the list
tests.append({
    'input': {
        'nums': [1, 4, 7, 9, 13, 16, 20, 22, 25]
    },
    'output': 0
})

# %%
# An empty list.
tests.append({
    'input': {
        'nums': []
    },
    'output': -1
})

# %%
def count_rotations_linear(nums):
    # If list is empty
    if len(nums) == 0:
        return -1
    
    else:
        position = 0
        
        # Loop until last position in nums
        while position <= len(nums)-2:                     

            # Success criteria: check whether the number at the current position is smaller than the one before it
            if position >= 0 and nums[position] > nums[position+1]:  
                return position + 1

            # Move to the next position
            position += 1
        
        # If list is unrotated
        return 0

# %%
def binary_search(lo, hi, condition, nums_len):
    while lo < hi:
        # Calculating mid position
        mid = (lo + hi) // 2 
        # result of binary search
        result = condition(mid, hi, lo)
        
        if result == 'found':
            return mid + 1
        elif result == 'left':
            # Dropping right half
            hi = mid
        elif result == 'right':
            # Dropping left half
            lo = mid + 1
        elif result == 'unrotated':
            return 0
    # "empty"    
    return -1

# %%
def count_rotations_binary(nums):
    
    def condition(mid, hi, lo):
        mid_number = nums[mid]
        
        if hi - lo == len(nums)-1 and nums[lo] < nums[hi]:
            # If list is unrotated
            return "unrotated"
        elif len(nums) == 1:
            return "unrotated"
        else:            
            # Success criteria: mid_number is greater or equal to number in lowest position and greater than the next
            if mid_number > nums[mid+1]:
                # The middle position is the answer
                return "found"
            elif mid_number > nums[lo]:
                # Answer lies in the right half
                return "right"
            elif mid_number < nums[lo]:
                # Answer lies in the left half
                return "left"
        
    return binary_search(0, len(nums)-1, condition, len(nums) // 2)

# %%
from time import perf_counter as timer
from  collections import Counter
import math

# %%
def evaluate_cases(count_rotations, tests, display=True):
    results = []
    i = 1
    for test in tests:
        # Timing the search opperation passed as "count_rotations"
        start = timer()
        position = count_rotations(test['input']['nums'])
        end = timer()
        
        if display:
            print("Test case #{}".format(i), "\n")
            print("Input:\n'nums': {}\n".format(test['input']['nums']))

            print("Expected position:\n{}\n".format(position))
            print("True position:\n{}\n".format(test['output']))

            print("Execution time:\n{:.2f} ms\n".format((end - start)*1e3))        
        else:
            print("Position:", position)
            print("Execution time: {:.2f} ms".format((end - start)*1e3))
        
        if position == test['output']:
            print("Test result:\nPASSED\n")
            results.append("passed")
        else:
            print("Test result:\nFAILED\n")
            results.append("failed")
        
        i += 1
        
    if display:
        print("SUMMARY:\n")
        print("TOTAL: {}".format(len(results)), 
              "PASSED: {}".format(Counter(results)['passed']), 
              "FAILED: {}\n".format(Counter(results)['failed']))

# %%
evaluate_cases(count_rotations_linear, tests)
# Out:
# Test case #1
#
# Input:
# 'nums': [19, 25, 29, 3, 5, 6, 7, 9, 11, 14]
#
# Expected position:
# 3
#
# True position:
# 3
#
# Execution time:
# 0.00 ms
#
# Test result:
# PASSED
#
# Test case #2
#
# Input:
# 'nums': [7, 9, 13, 14, 17, 2, 4, 5]
#
# Expected position:
# 5
#
# True position:
# 5
#
# Execution time:
# 0.01 ms
#
# Test result:
# PASSED
#
# Test case #3
#
# Input:
# 'nums': [2, 4, 6, 8, 9, 10]
#
# Expected position:
# 0
#
# True position:
# 0
#
# Execution time:
# 0.01 ms
#
# Test result:
# PASSED
#
# Test case #4
#
# Input:
# 'nums': [23, 4, 7, 9, 13, 16, 20, 22]
#
# Expected position:
# 1
#
# True position:
# 1
#
# Execution time:
# 0.00 ms
#
# Test result:
# PASSED
#
# Test case #5
#
# Input:
# 'nums': [3, 5, 7, 9, 10, 13, 15, 1]
#
# Expected position:
# 7
#
# True position:
# 7
#
# Execution time:
# 0.01 ms
#
# Test result:
# PASSED
#
# Test case #6
#
# Input:
# 'nums': [1, 4, 7, 9, 13, 16, 20, 22, 25]
#
# Expected position:
# 0
#
# True position:
# 0
#
# ...

# %%
evaluate_cases(count_rotations_binary, tests)
# Out:
# Test case #1
#
# Input:
# 'nums': [19, 25, 29, 3, 5, 6, 7, 9, 11, 14]
#
# Expected position:
# 3
#
# True position:
# 3
#
# Execution time:
# 0.01 ms
#
# Test result:
# PASSED
#
# Test case #2
#
# Input:
# 'nums': [7, 9, 13, 14, 17, 2, 4, 5]
#
# Expected position:
# 5
#
# True position:
# 5
#
# Execution time:
# 0.01 ms
#
# Test result:
# PASSED
#
# Test case #3
#
# Input:
# 'nums': [2, 4, 6, 8, 9, 10]
#
# Expected position:
# 0
#
# True position:
# 0
#
# Execution time:
# 0.00 ms
#
# Test result:
# PASSED
#
# Test case #4
#
# Input:
# 'nums': [23, 4, 7, 9, 13, 16, 20, 22]
#
# Expected position:
# 1
#
# True position:
# 1
#
# Execution time:
# 0.00 ms
#
# Test result:
# PASSED
#
# Test case #5
#
# Input:
# 'nums': [3, 5, 7, 9, 10, 13, 15, 1]
#
# Expected position:
# 7
#
# True position:
# 7
#
# Execution time:
# 0.01 ms
#
# Test result:
# PASSED
#
# Test case #6
#
# Input:
# 'nums': [1, 4, 7, 9, 13, 16, 20, 22, 25]
#
# Expected position:
# 0
#
# True position:
# 0
#
# ...

# %%
large_test = [{'input':
                 {'nums': range(0, 10000000)},
              'output': 0
             }]

# %%
evaluate_cases(count_rotations_linear, large_test, display=False)
# Out:
# Position: 0
# Execution time: 7407.06 ms
# Test result:
# PASSED

# %%
evaluate_cases(count_rotations_binary, large_test, display=False)
# Out:
# Position: 0
# Execution time: 0.01 ms
# Test result:
# PASSED
