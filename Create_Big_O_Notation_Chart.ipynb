# %%
import big_o

# %%
import matplotlib.pyplot as plt
import numpy as np
import timeit
import time
import math
import random
plt.rcParams['figure.figsize'] = [10, 6]

# %%
def linear_search(lst,target):
    for i in range(len(lst)):
        if(lst[i]== target):
            return i
    return -1
lst=np.linspace(10, 10_000, 100, dtype=int)
target=2
print(linear_search(lst,target))
if __name__ == '__main__':
    import timeit
    print(timeit.timeit("linear_search('lst','target')", setup="from __main__ import linear_search",number=1))
# Out:
# -1
# 2.300000005561742e-06

# %%
import matplotlib.pyplot as plt
target = range(1, 50, 10)
y_1 = []
y_2 = []


for n in target:
    lst= list(range(0, n))
    y_1.append(timeit.timeit(lambda: linear_search(lst, 1000)))
    y_2.append(timeit.timeit(lambda: linear_search(lst, 0)))
    
# %matplotlib notebook

import matplotlib.pyplot as plt
plt.plot(target,y_1,'r') 
plt.plot(target,y_2,'g') 

plt.ylim(ymin=0)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
reg= linear_model.LinearRegression()
reg.fit()
print(reg.predict)
print(reg.score)

# %%
def contains_1(lst, x):
    lo = 0
    hi = len(lst)-1
    while lo <= hi:
        mid = (lo + hi) // 2
        if x < lst[mid]:
            hi = mid - 1
        elif x > lst[mid]:
            lo = mid + 1
        else:
            return True
    else:
        return False
ns = np.linspace(10, 10_000, 100, dtype=int)
ts = [timeit.timeit('contains_1(lst, 0)', 
                    setup='lst=list(range({}))'.format(n),
                    globals=globals(),
                    number=1000)
      for n in ns]

def contains_1_generator(n):
    return deque(range(n))
plt.plot(ns, ts, 'or')
degree = 4
coeffs = np.polyfit(ns, ts, degree)
p = np.poly1d(coeffs)
plt.plot(ns, [p(n) for n in ns], '-b');
print(big_o.big_o(contains_1,contains_1_generator, n_measures=100)[0])
